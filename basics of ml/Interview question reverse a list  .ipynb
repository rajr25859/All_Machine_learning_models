# %%
arr = list(input('Enter The array:'))
if arr == arr[::-1]:
    print('Reverse is same')
else:
    print('Reverse is not same')
# Out:
# Enter The array:naveen\
# Reverse is not same

# %%
def reversesame(arr):
    if arr == arr[::-1]:
        print('Reverse is same')
    else:
        print('Reverse is not same')
arr = list(input('Enter The array:'))
reversesame(arr)
# Out:
# Enter The array:zahaz
# Reverse is same

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(100)

# %%
n1 = np.random.randint(18, 90, 300)

# %%
n2 = np.random.randn(300)

# %%
n3 = np.random.random(300)

# %%
n4 = 'ABCDEFGHIJKLMNOPQRSTUVWXY' * 12

# %%
data = pd.DataFrame({'ColA': list(n4), 'ColB': n1, 'ColC': n3, 'ColD': n2})
data
# Out:
#     ColA  ColB      ColC      ColD
# 0      A    26  0.500709  1.387602
# 1      B    42  0.500890 -1.735391
# 2      C    85  0.608903  0.288377
# 3      D    66  0.995365 -0.339085
# 4      E    28  0.247950  0.527369
# 5      F    70  0.738433 -0.374303
# 6      G    71  0.930044  0.477092
# 7      H    84  0.584412 -1.429763
# 8      I    32  0.880647  0.407707
# 9      J    52  0.692059 -0.828280
# 10     K    42  0.351418  0.423457
# 11     L    33  0.820699 -0.159517
# 12     M    78  0.237085  1.241082
# 13     N    76  0.921694  1.663536
# 14     O    34  0.918849 -0.661938
# 15     P    27  0.629531  3.465227
# 16     Q    20  0.512223  0.391439
# 17     R    45  0.299852  0.327245
# 18     S    22  0.451062 -0.311347
# 19     T    49  0.717144 -1.424656
# 20     U    19  0.289711 -0.624872
# 21     V    31  0.208844 -0.109995
# 22     W    22  0.316537  0.952959
# 23     X    77  0.573235 -0.983363
# 24     Y    85  0.462526 -1.094557
# 25     A    25  0.502619 -0.241349
# ...

# %%
data.shape
# Out:
# (300, 4)

# %%
data.columns
# Out:
# Index(['ColA', 'ColB', 'ColC', 'ColD'], dtype='object')

# %%
data.head()
# Out:
#   ColA  ColB      ColC      ColD
# 0    A    26  0.500709  1.387602
# 1    B    42  0.500890 -1.735391
# 2    C    85  0.608903  0.288377
# 3    D    66  0.995365 -0.339085
# 4    E    28  0.247950  0.527369

# %%
data.sum()
# Out:
# ColA    ABCDEFGHIJKLMNOPQRSTUVWXYABCDEFGHIJKLMNOPQRSTU...
# ColB                                                15945
# ColC                                              150.845
# ColD                                              17.9339
# dtype: object

# %%
data.mean()
# Out:
# ColB    53.150000
# ColC     0.502817
# ColD     0.059780
# dtype: float64

# %%
data.aggregate('sum')
# Out:
# ColA    ABCDEFGHIJKLMNOPQRSTUVWXYABCDEFGHIJKLMNOPQRSTU...
# ColB                                                15945
# ColC                                              150.845
# ColD                                              17.9339
# dtype: object

# %%
data.agg('sum')
# Out:
# ColA    ABCDEFGHIJKLMNOPQRSTUVWXYABCDEFGHIJKLMNOPQRSTU...
# ColB                                                15945
# ColC                                              150.845
# ColD                                              17.9339
# dtype: object

# %%
data.agg(['sum', 'mean', 'max', 'min'])

# %%
data[['ColC', 'ColD']].agg(['sum', 'mean', 'median', 'max', 'min'])

# %%
data[['ColC', 'ColD']].agg('sum')

# %%
data[['ColC', 'ColD']].agg('mean')

# %%
data.agg({'ColC': 'sum', 'ColD': 'sum'})

# %%
data.agg({'ColC': 'sum', 'ColD': 'mean'})

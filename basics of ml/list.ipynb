# %%
l = list(input('Enter the list of char : '))
# Out:
# Enter the list of char : mkdfhlg;e'f,.,anfld

# %%
l
# Out:
# ['m',
#  'k',
#  'd',
#  'f',
#  'h',
#  'l',
#  'g',
#  ';',
#  'e',
#  "'",
#  'f',
#  ',',
#  '.',
#  ',',
#  'a',
#  'n',
#  'f',
#  'l',
#  'd']

# %%
first_l_ascii = []

# %%
for i in l:
    first_l_ascii.append(ord(i))

# %%
first_l_ascii
# Out:
# [109,
#  107,
#  100,
#  102,
#  104,
#  108,
#  103,
#  59,
#  101,
#  39,
#  102,
#  44,
#  46,
#  44,
#  97,
#  110,
#  102,
#  108,
#  100]

# %%
rev_first = first_l_ascii[::-1]

# %%
rev_first
# Out:
# [100,
#  108,
#  102,
#  110,
#  97,
#  44,
#  46,
#  44,
#  102,
#  39,
#  101,
#  59,
#  103,
#  108,
#  104,
#  102,
#  100,
#  107,
#  109]

# %%
len(rev_first)
# Out:
# 19

# %%
f_sub_list = []

# %%
for i in range(len(rev_first)-1):
        sub_1 = abs(rev_first[i]-rev_first[i+1])
        f_sub_list.append(sub_1)

# %%
f_sub_list
# Out:
# [8, 6, 8, 13, 53, 2, 2, 58, 63, 62, 42, 44, 5, 4, 2, 2, 7, 2]

# %%
first_l_ascii
# Out:
# [109,
#  107,
#  100,
#  102,
#  104,
#  108,
#  103,
#  59,
#  101,
#  39,
#  102,
#  44,
#  46,
#  44,
#  97,
#  110,
#  102,
#  108,
#  100]

# %%
s_sub_list = []

# %%
for i in range(len(first_l_ascii)-1):
    sub_2 = abs(first_l_ascii[i]-first_l_ascii[i+1])
    s_sub_list.append(sub_2)

# %%
s_sub_list
# Out:
# [2, 7, 2, 2, 4, 5, 44, 42, 62, 63, 58, 2, 2, 53, 13, 8, 6, 8]

# %%
sorted(s_sub_list)
# Out:
# [2, 2, 2, 2, 2, 4, 5, 6, 7, 8, 8, 13, 42, 44, 53, 58, 62, 63]

# %%
sorted(f_sub_list)
# Out:
# [2, 2, 2, 2, 2, 4, 5, 6, 7, 8, 8, 13, 42, 44, 53, 58, 62, 63]

# %%
if sorted(f_sub_list) == sorted(s_sub_list):
    print('funny')
else:
    print('not funny')
# Out:
# funny

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Create a variable

# %%
 # intialise data of lists.
data = {'Name':['Rohit', 'Aniket', 'Rishabh', 'Abhishek'],
        'Age':[21, 20, 21, 18]}

# %% [markdown]
# ## Create a Dataframe

# %%
# Create DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# ## Output

# %%
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        Name  Age
# 0     Rohit   21
# 1    Aniket   20
# 2   Rishabh   21
# 3  Abhishek   18

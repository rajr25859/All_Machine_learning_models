# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(100)

# %%
n1 = np.random.randint(18, 90, 300)

# %%
n2 = np.random.randn(300)

# %%
n3 = np.random.random(300)

# %%
n4 = 'ABCDEFGHIJKLMNOPQRSTUVWXY' * 12

# %%
data = pd.DataFrame({'ColA': list(n4), 'ColB': n1, 'ColC': n3, 'ColD': n2})

# %%
data.shape
# Out:
# (300, 4)

# %%
data.columns
# Out:
# Index(['ColA', 'ColB', 'ColC', 'ColD'], dtype='object')

# %%
data.head()
# Out:
#   ColA  ColB      ColC      ColD
# 0    A    26  0.500709  1.387602
# 1    B    42  0.500890 -1.735391
# 2    C    85  0.608903  0.288377
# 3    D    66  0.995365 -0.339085
# 4    E    28  0.247950  0.527369

# %%
data.sum()
# Out:
# ColA    ABCDEFGHIJKLMNOPQRSTUVWXYABCDEFGHIJKLMNOPQRSTU...
# ColB                                                15945
# ColC                                              150.845
# ColD                                              17.9339
# dtype: object

# %%
data.mean()
# Out:
# ColB    53.150000
# ColC     0.502817
# ColD     0.059780
# dtype: float64

# %%
data.aggregate('sum')
# Out:
# ColA    ABCDEFGHIJKLMNOPQRSTUVWXYABCDEFGHIJKLMNOPQRSTU...
# ColB                                                15945
# ColC                                              150.845
# ColD                                              17.9339
# dtype: object

# %%
data.agg('sum')
# Out:
# ColA    ABCDEFGHIJKLMNOPQRSTUVWXYABCDEFGHIJKLMNOPQRSTU...
# ColB                                                15945
# ColC                                              150.845
# ColD                                              17.9339
# dtype: object

# %%
data.agg(['sum', 'mean', 'max', 'min'])
# Out:
#                                                    ColA      ColB        ColC  \
# sum   ABCDEFGHIJKLMNOPQRSTUVWXYABCDEFGHIJKLMNOPQRSTU...  15945.00  150.844961
# max                                                   Y     89.00    0.996965
# min                                                   A     18.00    0.000799
# mean                                                NaN     53.15    0.502817
#
#            ColD
# sum   17.933869
# max    3.465227
# min   -2.305258
# mean   0.059780

# %%
data[['ColC', 'ColD']].agg(['sum', 'mean', 'median', 'max', 'min'])
# Out:
#               ColC       ColD
# sum     150.844961  17.933869
# mean      0.502817   0.059780
# median    0.501754   0.016817
# max       0.996965   3.465227
# min       0.000799  -2.305258

# %%
data[['ColC', 'ColD']].agg('sum')
# Out:
# ColC    150.844961
# ColD     17.933869
# dtype: float64

# %%
data[['ColC', 'ColD']].agg('mean')
# Out:
# ColC    0.502817
# ColD    0.059780
# dtype: float64

# %%
data.agg({'ColC': 'sum', 'ColD': 'sum'})
# Out:
# ColC    150.844961
# ColD     17.933869
# dtype: float64

# %%
data.agg({'ColC': 'sum', 'ColD': 'mean'})
# Out:
# ColC    150.844961
# ColD      0.059780
# dtype: float64

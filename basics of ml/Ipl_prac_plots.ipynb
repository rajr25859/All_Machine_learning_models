# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\DATA FOR MACHINE LEARNING PROJECT\\Training data  testing datasets for machine learning\\ipl_stat.csv")

# %%
df
# Out:
#    POS          PLAYER  Mat  Inns  NO  Runs    HS    Avg    BF      SR  100  \
# 0    1    Suresh Raina  176   172  27  4985  100*  34.37  3600  138.47    1
# 1    2     Virat Kohli  163   155  26  4948   113  38.35  3784  130.76    4
# 2    3    Rohit Sharma  173   168  27  4493  109*  31.86  3429  131.02    1
# 3    4  Gautam Gambhir  154   152  17  4217    93  31.23  3404  123.88    0
# 4    5   Robin Uthappa  165   158  15  4086    87  28.57  3099  131.84    0
# 5    6  Shikhar Dhawan  143   142  20  4058   95*  33.26  3285  123.53    0
# 6    7        MS Dhoni  175   158  58  4016   79*  40.16  2906  138.19    0
# 7    8    David Warner  114   114  15  4014   126  40.54  2824  142.13    3
# 8    9     Chris Gayle  112   111  14  3994  175*  41.17  2650  150.71    6
# 9   10  AB de Villiers  141   129  29  3953  133*  39.53  2619  150.93    3
#
#    50   4s   6s
# 0  35  448  185
# 1  34  434  178
# 2  34  379  184
# 3  36  491   59
# 4  23  401  145
# 5  32  460   85
# ...

# %%
x = df['PLAYER']
y = df['Runs']

# %%
plt.figure(figsize = (18,8))
plt.plot(x,y)
plt.show()

# %%
names = ['Aniket','Abhishek','Rishabh','Rohit','Shubhav','Anshul']
age   = [190, 100, 210, 50, 90, 40]

# %%
plt.plot(names,age)
plt.show()

# %%
plt.bar(names,age)
plt.show()

# %%
plt.scatter(names,age)
plt.show()

# %%
plt.pie(age)
plt.show()

# %%
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
path = 'D:\DATA FOR MACHINE LEARNING PROJECT\MNIST_model_project\mlengine\pics prediction'
l = os.listdir(path)
img = []
for i in l:
    image = plt.imread(f'D:\DATA FOR MACHINE LEARNING PROJECT\MNIST_model_project\mlengine\pics prediction\{i}')
    # f_img = image.flatten().reshape(28, 28)
    img.append(image.flatten())

# %%
img = np.asarray(img)

# %%
img.shape
# Out:
# (111, 784)

# %%
plt.imshow(img[0].reshape(28, 28))

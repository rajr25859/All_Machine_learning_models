# %%
from sklearn.datasets import load_digits

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
mnist = load_digits()

# %%
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'images', 'DESCR'])

# %%
images = mnist['images']

# %%
images.shape
# Out:
# (1797, 8, 8)

# %%
X = mnist['data']

# %%
y = mnist['target']

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
rfc = RandomForestClassifier()
rfc = rfc.fit(X_train, y_train)

# %%
y_pred = rfc.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9472222222222222

# %%
classification_report(y_test, y_pred)
# Out:
# '             precision    recall  f1-score   support\n\n          0       0.93      0.98      0.95        42\n          1       0.89      0.97      0.93        32\n          2       0.97      0.93      0.95        41\n          3       0.91      0.94      0.92        32\n          4       0.92      0.92      0.92        36\n          5       1.00      0.91      0.96        35\n          6       1.00      0.95      0.97        40\n          7       0.95      0.97      0.96        39\n          8       0.92      0.89      0.91        27\n          9       0.97      1.00      0.99        36\n\navg / total       0.95      0.95      0.95       360\n'

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
ac  = {}
cl = {}

algo_names = ['KNeighborsClassifier', 'DecisionTreeClassifier','RandomForestClassifier', 'GaussianNB', 'LogisticRegression','SVC']
algos = [ KNeighborsClassifier(n_neighbors=5), DecisionTreeClassifier(),RandomForestClassifier(n_estimators=10),GaussianNB(), LogisticRegression(), SVC(gamma='auto')]


for algo_names, algo in zip(algo_names,  algos):
    al = algo
    al.fit(X_train, y_train)
    y_pred = al.predict(X_test)
    
    
    ac[algo_names] = [accuracy_score(y_test, y_pred)]
    cl[algo_names] = [classification_report(y_test, y_pred)]

    

    
    
algo_ac = pd.DataFrame.from_dict(ac, orient = 'index',columns = ['accuracy_score'])
algo_cl = pd.DataFrame.from_dict(cl, orient = 'index', columns = ['classification_report'])
algo_test = pd.DataFrame([algo_ac['accuracy_score'], algo_cl['classification_report']]).T.reset_index()


algo_test
# Out:
#                     index accuracy_score  \
# 0    KNeighborsClassifier       0.986111
# 1  DecisionTreeClassifier          0.875
# 2  RandomForestClassifier       0.952778
# 3              GaussianNB       0.838889
# 4      LogisticRegression       0.958333
# 5                     SVC       0.530556
#
#                                classification_report
# 0               precision    recall  f1-score   s...
# 1               precision    recall  f1-score   s...
# 2               precision    recall  f1-score   s...
# 3               precision    recall  f1-score   s...
# 4               precision    recall  f1-score   s...
# 5               precision    recall  f1-score   s...

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from keras.preprocessing import image
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-4ccb2e9aaa4c> in <module>()
#       6 from sklearn.model_selection import train_test_split
#       7 from sklearn.metrics import accuracy_score, confusion_matrix
# ----> 8 from keras.preprocessing import image
#       9 from PIL import Image
#
# ModuleNotFoundError: No module named 'keras'

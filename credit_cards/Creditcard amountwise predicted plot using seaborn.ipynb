# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('creditcard.csv')
# df.head()

# %%
# df.info()

# %%
X = df['Class'].values
X.shape
# Out:
# (284807,)

# %%
valid = 0 
non_valid = 0
for i in X:
    if i==0:
        valid+=1
    if i ==1:
        non_valid+=1

# %%
tran = [valid, non_valid]

# %%
non_valid
# Out:
# 492

# %%
trans = np.array(df['Class'].value_counts())

# %%
sns.lineplot(x = df["Class"], y = df["Amount"])

# %%
sns.pointplot(x = df['Class'],y = df['Amount'])

# %%
plt.figure(figsize = (8,8))

plt.pie(tran, explode = [.9,0])
plt.show()

# %%
var = [df["Amount"].min(),df["Amount"].max()]

# %%
classes = 0,1

# %%
sns.pointplot(var,classes).set_title("Min Max Variance",fontdict = {'fontsize':38})
# Out:
# Text(0.5,1,'Min Max Variance')

# %%
plt.hist(df["Amount"])
# Out:
# (array([2.84395e+05, 3.60000e+02, 3.60000e+01, 1.00000e+01, 2.00000e+00,
#         1.00000e+00, 0.00000e+00, 2.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([    0.   ,  2569.116,  5138.232,  7707.348, 10276.464, 12845.58 ,
#         15414.696, 17983.812, 20552.928, 23122.044, 25691.16 ]),
#  <a list of 10 Patch objects>)

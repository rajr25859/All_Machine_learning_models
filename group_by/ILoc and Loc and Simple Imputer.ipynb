# %%
import sklearn
sklearn.__version__
# Out:
# '0.19.2'

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
# from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import Imputer
import random

# %%
df=pd.read_csv("uk-500.csv")
df.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
df['id'] = [random.randint(0,1000) for x in range(df.shape[0])]

# %%
df.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %% [markdown]
# # Selecting pandas data using “iloc”

# %%
df.iloc[:3]
# Out:
#   first_name   last_name             company_name       address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc  14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America   5 Binney St
# 2     France     Andrade      Elliott, John W Esq  8 Moor Place
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  787
# 1     http://www.capgeminiamerica.co.uk  178
# 2      http://www.elliottjohnwesq.co.uk  171

# %%
df.iloc[:3 , :2]
# Out:
#   first_name   last_name
# 0    Aleshia  Tomkiewicz
# 1       Evan   Zigomalas
# 2     France     Andrade

# %%
df.iloc[[0,3,6,24], [0,5,6]]
# Out:
#    first_name        county    postal
# 0     Aleshia          Kent   CT2 7PP
# 3     Ulysses  Lincolnshire  DN36 5RP
# 6        Marg   Southampton  SO14 3TY
# 24       Tess   West Sussex  PO19 1RH

# %%
df.loc[:2, 'first_name']
# Out:
# 0    Aleshia
# 1       Evan
# 2     France
# Name: first_name, dtype: object

# %%
df.loc[:3 , ['first_name' , 'county']]
# Out:
#   first_name           county
# 0    Aleshia             Kent
# 1       Evan  Buckinghamshire
# 2     France      Bournemouth
# 3    Ulysses     Lincolnshire

# %%
df.iloc[:1 , :3]
# Out:
#   first_name   last_name             company_name
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc

# %%
df.iloc[:3, :5]
# Out:
#   first_name   last_name             company_name       address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc  14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America   5 Binney St
# 2     France     Andrade      Elliott, John W Esq  8 Moor Place
#
#                              city
# 0               St. Stephens Ward
# 1                      Abbey Ward
# 2  East Southbourne and Tuckton W

# %%
df.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
df.dropna(axis=0 )
# Out:
#       first_name   last_name                    company_name  \
# 0        Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1           Evan   Zigomalas              Cap Gemini America
# 2         France     Andrade             Elliott, John W Esq
# 3        Ulysses   Mcwalters                  Mcmahan, Ben L
# 4         Tyisha      Veness                  Champagne Room
# 5           Eric       Rampy         Thompson, Michael C Esq
# 6           Marg    Grasmick   Wrangle Hill Auto Auct & Slvg
# 7        Laquita       Hisaw           In Communications Inc
# 8           Lura    Manzella                 Bizerba Usa Inc
# 9         Yuette      Klapec                       Max Video
# 10      Fernanda      Writer            K & R Associates Inc
# 11   Charlesetta         Erm                Cain, John M Esq
# 12      Corrinne       Jaret               Sound Vision Corp
# 13        Niesha       Bruch          Rowley/hansell Petetin
# ...

# %%
np.nan
# Out:
# nan

# %%
data = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f', 'h'],columns=['one', 'two', 'three'])

# %%
data['four'] = 'bar'
data['five'] = data['one'] > 0


data
# Out:
#         one       two     three four   five
# a  0.629377 -0.137526  1.294765  bar   True
# c -1.599677  1.509704  0.183807  bar  False
# e -0.787029 -0.905787  1.878208  bar  False
# f  0.111475 -0.241675  0.209180  bar   True
# h -2.402364  0.819923 -0.692477  bar  False

# %%
data2 = data.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
data2
# Out:
#         one       two     three four   five
# a  0.629377 -0.137526  1.294765  bar   True
# b       NaN       NaN       NaN  NaN    NaN
# c -1.599677  1.509704  0.183807  bar  False
# d       NaN       NaN       NaN  NaN    NaN
# e -0.787029 -0.905787  1.878208  bar  False
# f  0.111475 -0.241675  0.209180  bar   True
# g       NaN       NaN       NaN  NaN    NaN
# h -2.402364  0.819923 -0.692477  bar  False

# %%
data2.dropna()
# Out:
#         one       two     three four   five
# a  0.629377 -0.137526  1.294765  bar   True
# c -1.599677  1.509704  0.183807  bar  False
# e -0.787029 -0.905787  1.878208  bar  False
# f  0.111475 -0.241675  0.209180  bar   True
# h -2.402364  0.819923 -0.692477  bar  False

# %%
data2.fillna('raj')
# Out:
#         one       two     three four   five
# a  0.629377 -0.137526   1.29477  bar   True
# b       raj       raj       raj  raj    raj
# c  -1.59968    1.5097  0.183807  bar  False
# d       raj       raj       raj  raj    raj
# e -0.787029 -0.905787   1.87821  bar  False
# f  0.111475 -0.241675   0.20918  bar   True
# g       raj       raj       raj  raj    raj
# h  -2.40236  0.819923 -0.692477  bar  False

# %%
data2.fillna('raj')
# Out:
#         one       two     three four   five
# a  0.629377 -0.137526   1.29477  bar   True
# b       raj       raj       raj  raj    raj
# c  -1.59968    1.5097  0.183807  bar  False
# d       raj       raj       raj  raj    raj
# e -0.787029 -0.905787   1.87821  bar  False
# f  0.111475 -0.241675   0.20918  bar   True
# g       raj       raj       raj  raj    raj
# h  -2.40236  0.819923 -0.692477  bar  False

# %%
data2.isna()
# Out:
#      one    two  three   four   five
# a  False  False  False  False  False
# b   True   True   True   True   True
# c  False  False  False  False  False
# d   True   True   True   True   True
# e  False  False  False  False  False
# f  False  False  False  False  False
# g   True   True   True   True   True
# h  False  False  False  False  False

# %%
data2.notna()
# Out:
#      one    two  three   four   five
# a   True   True   True   True   True
# b  False  False  False  False  False
# c   True   True   True   True   True
# d  False  False  False  False  False
# e   True   True   True   True   True
# f   True   True   True   True   True
# g  False  False  False  False  False
# h   True   True   True   True   True

# %% [markdown]
# # Simple Imputer

# %%
imp = Imputer(missing_values=np.nan, strategy='mean')

# %%
# imp.fit([[1, 2], [np.nan, 3], [7, 6]])

# %%
X = [[np.nan, 2],
     [6, np.nan],
     [7, 6]]
imp.fit(X)
# Out:
# Imputer(axis=0, copy=True, missing_values=nan, strategy='mean', verbose=0)

# %%
print(imp.transform(X))
# Out:
# [[6.5 2. ]
#  [6.  4. ]
#  [7.  6. ]]
